# %%
import csv
from datetime import datetime
import matplotlib.pyplot as plt
from statistics import mean, stdev, median, variance
import os
from tabulate import tabulate;
import numpy as np

# %%
path_phasep = './AA/AAS_all_phasenet_p_picks_nometal.csv'
path_phases = './AA/AAS_all_phasenet_s_picks_nometal.csv'
path_handp = './AA/AAS_all_hand_p_picks.csv'
path_hands = './AA/AAS_all_hand_s_picks.csv'
path_arpickp = './AA/AAS_all_arpick_p_picks.csv'
path_arpicks = './AA/AAS_all_arpick_s_picks.csv'

TPlim = 0.30
Pplim = 0.60
Pslim = 0.40

# %%
path_project_home = '/Users/utkuunal/Desktop/Projects/ProjectA'
os.chdir('{}'.format(path_project_home))

# %%
phasep = []
with open(path_phasep) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        phasep.append(row)
print(len(phasep))
print(phasep[:10])
phases = []
with open(path_phases) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        phases.append(row)
print(len(phases))
print(phases[:10])
# Out:
# 6178
# ...

# %%
arpickp = []
with open(path_arpickp) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        arpickp.append(row)
print(len(arpickp))
print(arpickp[:10])
arpicks = []
with open(path_arpicks) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        arpicks.append(row)
print(len(arpicks))
print(arpicks[:10])
# Out:
# 7089
# [['20200514_011723--40.81-25.59--Ke-EGE-DENIZI.M=2.0/RDO.HH', '2020-05-14T01:17:30.57', 'P'], ['20200514_011723--40.81-25.59--Ke-EGE-DENIZI.M=2.0/ALN.HH', '2020-05-14T01:17:30.66', 'P'], ['20200514_011723--40.81-25.59--Ke-EGE-DENIZI.M=2.0/ENEZ.BH', '2020-05-14T01:17:32.38', 'P'], ['20200514_011723--40.81-25.59--Ke-EGE-DENIZI.M=2.0/GADA.BH', '2020-05-14T01:17:36.68', 'P'], ['20200514_011723--40.81-25.59--Ke-EGE-DENIZI.M=2.0/ERIK.BH', '2020-05-14T01:17:37.16', 'P'], ['20200514_011723--40.81-25.59--Ke-EGE-DENIZI.M=2.0/GELI.BH', '2020-05-14T01:17:38.76', 'P'], ['20200514_011723--40.81-25.59--Ke-EGE-DENIZI.M=2.0/KDZ.HH', '2020-05-14T01:17:38.61', 'P'], ['20200514_011723--40.81-25.59--Ke-EGE-DENIZI.M=2.0/COMU.HH', '2020-05-14T01:17:42.98', 'P'], ['20200514_011723--40.81-25.59--Ke-EGE-DENIZI.M=2.0/BOZC.BH', '2020-05-14T01:17:43.05', 'P'], ['20200514_021748--39.59-26.09--Ke-TUZLA-AYVACIK-(CANAKKALE).M=1.3/BOZC.BH', '2020-05-14T02:17:54.52', 'P']]
# 6860
# ...

# %%
handp = []
with open(path_handp) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        handp.append(row)
print(len(handp))
print(handp[:10])
hands = []
with open(path_hands) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        hands.append(row)
print(len(hands))
print(hands[:10])
# Out:
# 7090
# ...

# %%
import collections
phasep_lim = 0
for pp in phasep:
    if float(pp[3]) >= Pplim:
        phasep_lim += 1
phases_lim = 0
for ps in phases:
    if float(ps[3]) >= Pslim:
        phases_lim += 1        
print("{:<68} {:<5} {:<5}".format('Handpicks P, S: ', str(len(handp)) + ',', len(hands)))
print("{:<68} {:<5} {:<5}".format('PhaseNet picks P, S: ', str(phasep_lim) + ',', str(phases_lim)))
phaseeqs = []
i = 0
for pp in phasep:
    if float(pp[3]) >= Pplim:
        for ps in phases:
            if float(ps[3]) >= Pslim:
                if pp[0] == ps[0]:
                    phaseeqs.append(pp[0].split('/')[0])
                    i += 1
print("{:<68} {:<15}".format('PhaseNet P-S pick-pairs (For the same event): ', i))
i = 0
for hs in hands:
    for ps in phases:
        if float(ps[3]) >= Pslim:
            if hs[0] == ps[0]:
                i += 1
#print("{:<68} {:<15}".format('Handpicked S picks matching PhaseNet S picks', i))
print("{:<68} {:<15}".format('Extra S Handpicks (No corresponding PhaseNet S pick)', len(hands)-i))
print("{:<68} {:<15}".format('Extra PhaseNet S picks (No corresponding S Handpick)', phases_lim-i))
handpickeqs = []
hpstas = []
hpeqs = []
i = 0
for hp in handp:
    if hp[0].split('/')[0] not in hpeqs:
        hpeqs.append(hp[0].split('/')[0])
    if hp[0].split('/')[1] not in hpstas:
        hpstas.append(hp[0].split('/')[1])
    for hs in hands:
        if hp[0] == hs[0]:
            handpickeqs.append(hp[0].split('/')[0])
            i += 1
print(len(handpickeqs), len(hpeqs), len(hpstas))
i = [item for item, count in collections.Counter(handpickeqs).items() if count > 0]
print("{:<68} {:<15}".format('Number of EQs in Handpicked P-S pairs : ', len(i)))
i = [item for item, count in collections.Counter(handpickeqs).items() if count > 2]
print("{:<68} {:<15}".format('Number of EQs in Handpicked P-S pairs with at least 3 stations: ', len(i)))
i = [item for item, count in collections.Counter(phaseeqs).items() if count > 0]
print("{:<68} {:<15}".format('Number of EQs in PhaseNet P-S pairs : ', len(i)))
i = [item for item, count in collections.Counter(phaseeqs).items() if count > 2]
print("{:<68} {:<15}".format('Number of Earthquakes in PhaseNet P-S pick-pairs with at least 3 stations: ', len(i)))
# Out:
# Handpicks P, S:                                                      7090, 3684
# PhaseNet picks P, S:                                                 4894, 4921
# PhaseNet P-S pick-pairs (For the same event):                        4036
# Extra S Handpicks (No corresponding PhaseNet S pick)                 888
# Extra PhaseNet S picks (No corresponding S Handpick)                 2125
# 3684 944 118
# Number of EQs in Handpicked P-S pairs :                              918
# Number of EQs in Handpicked P-S pairs with at least 3 stations:      621
# Number of EQs in PhaseNet P-S pairs :                                920
# Number of Earthquakes in PhaseNet P-S pick-pairs with at least 3 stations:  645

# %%
peqs = []
for hp in handp:
    if hp[0].split('/')[0] not in peqs:
        peqs.append(hp[0].split('/')[0])
print(len(peqs))
pstations = []
for hp in handp:
    if hp[0].split('/')[1] not in pstations:
        pstations.append(hp[0].split('/')[1])
print(len(pstations))
# Out:
# 944
# 118

# %%
seqs = []
for hs in hands:
    if hs[0].split('/')[0] not in seqs:
        seqs.append(hs[0].split('/')[0])
print(len(seqs))
sstations = []
for hs in hands:
    if hs[0].split('/')[1] not in sstations:
        sstations.append(hs[0].split('/')[1])
print(len(sstations))
# Out:
# 918
# 65

# %%
x_p = []
pp_TP = 0
pp_FP = 0
pp_FN = 0
pp_TN = 0
for pp in phasep:
    for hp in handp:
        if pp[0] == hp[0]:
            a = datetime.strptime(hp[1], '%Y-%m-%dT%H:%M:%S.%f')
            b = datetime.strptime(pp[1], '%Y-%m-%dT%H:%M:%S.%f')
            diff = a - b
            if float(pp[3]) >= Pplim:
                x_p.append(diff.total_seconds())
                if abs(diff.total_seconds()) <= TPlim:
                    pp_TP += 1
                else:
                    pp_FP += 1
            else:
                if abs(diff.total_seconds()) <= TPlim:
                    pp_FN += 1
                else:
                    pp_TN += 1

print('PhaseNet P true positives TP: ', pp_TP)
print('PhaseNet P false positives FP: ', pp_FP)
print('PhaseNet P false negatives: FN ', pp_FN)
print('PhaseNet P true negatives: TN ', pp_TN)
print('Total is: ', pp_TP + pp_FP + pp_FN + pp_TN)

pp_precision = pp_TP / (pp_TP + pp_FP)
pp_recall = pp_TP / (pp_TP + pp_FN)
pp_f1 = 2 * (pp_precision * pp_recall) / (pp_precision + pp_recall)

print(len(x_p))
print(x_p[:100])
# Out:
# PhaseNet P true positives TP:  2722
# PhaseNet P false positives FP:  2170
# PhaseNet P false negatives: FN  349
# PhaseNet P true negatives: TN  935
# Total is:  6176
# 4892
# [-0.06, -0.01, 0.06, -0.01, 0.62, 0.5, 1.34, -0.15, 0.41, -0.49, -0.34, 0.23, -0.35, 0.22, 0.03, -0.08, -0.32, -0.08, 0.1, 0.42, 0.07, 0.19, 0.08, 0.02, -0.06, 0.26, 0.01, 0.03, 0.74, 0.37, 0.13, 0.17, 0.42, 1.13, 2.09, -0.14, -0.02, 0.03, 0.18, 0.9, -0.21, 0.09, 1.07, -0.06, -0.17, 0.57, 1.02, 1.66, 1.15, 1.2, 0.3, 0.34, 3.07, 0.37, 0.79, 0.12, -0.02, 0.26, -0.15, -0.12, 0.38, 0.32, 0.64, -0.3, -0.06, 5.0, 1.14, 1.37, 1.37, 0.17, 0.14, 0.09, 0.09, 0.05, -0.02, 0.26, 0.81, -0.67, -0.03, 0.23, -0.14, 1.11, 0.7, 1.01, 2.56, 1.06, 1.05, 0.97, 1.89, 0.91, 1.62, 0.03, -0.02, 0.11, 0.81, 0.1, 0.39, 0.36, 0.13, 1.19]

# %%
x_s = []
ps_TP = 0
ps_FP = 0
ps_FN = 0
ps_TN = 0
for ps in phases:
    for hs in hands:
        if ps[0] == hs[0]:
            a = datetime.strptime(hs[1], '%Y-%m-%dT%H:%M:%S.%f')
            b = datetime.strptime(ps[1], '%Y-%m-%dT%H:%M:%S.%f')
            diff = a - b
            if float(ps[3]) >= Pslim:
                x_s.append(diff.total_seconds())
                if abs(diff.total_seconds()) <= TPlim:
                    ps_TP += 1
                else:
                    ps_FP += 1
            else:
                if abs(diff.total_seconds()) <= TPlim:
                    ps_FN += 1
                else:
                    ps_TN += 1                
                
print('PhaseNet S true positives TP: ', ps_TP)
print('PhaseNet S false positives FP: ', ps_FP)
print('PhaseNet S false negatives: FN ', ps_FN)
print('PhaseNet S true negatives: TN ', ps_TN)
print('Total is: ', ps_TP + ps_FP + ps_FN + ps_TN)

ps_precision = ps_TP / (ps_TP + ps_FP)
ps_recall = ps_TP / (ps_TP + ps_FN)
ps_f1 = 2 * (ps_precision * ps_recall) / (ps_precision + ps_recall)

print(len(x_s))
print(x_s[:100])
# Out:
# PhaseNet S true positives TP:  1308
# PhaseNet S false positives FP:  1488
# PhaseNet S false negatives: FN  78
# PhaseNet S true negatives: TN  265
# Total is:  3139
# 2796
# [-0.24, 0.33, 0.41, -0.52, 1.18, -0.3, -1.7, -0.14, -0.18, 0.75, -0.71, 16.8, 0.08, 0.26, -0.17, 0.21, 0.17, -0.46, -0.18, 0.18, 0.45, 0.17, 0.84, 0.58, 1.18, -0.08, -0.46, 0.43, 0.84, -1.8, 0.31, 0.87, -0.37, 0.76, -0.65, 0.3, 0.68, -0.15, 1.18, -0.82, 0.16, 0.37, 0.13, 0.86, 0.76, 0.49, 0.3, -0.03, -0.03, -0.03, 5.3, 0.51, 0.46, -0.02, -0.03, 0.26, 0.47, 2.61, -0.06, 0.08, 0.85, -0.66, 0.11, -0.83, -0.81, 1.76, 2.09, 0.33, 0.09, 0.13, 0.89, 0.29, 0.67, 0.84, 0.46, 0.22, 0.46, 1.25, -0.24, 1.15, 1.94, 0.38, -0.23, -0.04, 0.27, 0.42, -0.23, -0.78, -0.7, -0.13, 1.94, -0.53, -0.77, -0.12, 0.75, 0.7, 0.62, 0.75, 0.34, -0.93]

# %%
z_p = []
ap_TP = 0
ap_FP = 0
for ap in arpickp:
    for hp in handp:
        if ap[0] == hp[0]:
            a = datetime.strptime(hp[1], '%Y-%m-%dT%H:%M:%S.%f')
            b = datetime.strptime(ap[1], '%Y-%m-%dT%H:%M:%S.%f')
            diff = a - b
            z_p.append(diff.total_seconds())
            if abs(diff.total_seconds()) <= TPlim:
                ap_TP += 1
            else:
                ap_FP += 1
                
print('ARPick P true positives TP: ', ap_TP)
print('ARPick P false positives FP: ', ap_FP)
ap_FN = len(handp) - ap_TP
print('ARPick P false negatives: FN ', ap_FN)

ap_precision = ap_TP / (ap_TP + ap_FP)
ap_recall = ap_TP / (ap_TP + ap_FN)
ap_f1 = 2 * ap_precision * ap_recall / (ap_precision + ap_recall)

print(len(z_p))
print(z_p[:100])
# Out:
# ARPick P true positives TP:  2826
# ARPick P false positives FP:  4263
# ARPick P false negatives: FN  4264
# 7089
# [-0.03, 0.02, 0.04, 0.0, 0.45, 0.3, 1.33, -0.18, 0.43, -0.47, -0.29, 0.25, 3.31, 3.46, 3.13, -0.24, 0.22, -5.64, -3.28, -0.13, 4.68, 0.03, -0.06, -0.3, -0.13, 0.15, 0.44, 0.24, 3.42, 0.09, 3.76, 0.2, 1.76, 0.06, 0.0, 0.2, 0.02, 0.01, 0.71, 0.4, 0.22, 0.19, 0.43, 1.0, 2.04, -0.11, -0.05, 0.1, 2.91, 0.26, 0.43, 0.92, -0.18, 0.06, 1.09, -0.04, -0.17, 0.63, 1.0, 1.69, 1.15, 1.17, 1.0, -1.25, 0.32, 0.35, 1.84, 3.02, 0.38, 0.83, 0.19, 0.0, 0.29, -0.06, -0.15, 0.27, 0.2, 0.57, -8.35, 3.52, -0.3, -0.03, 4.5, 1.29, -1.28, 1.34, 2.75, 2.86, 3.33, 0.23, 0.18, 0.12, 0.14, 0.05, 4.1, -3.12, 0.04, 3.44, 0.82, 3.04]

# %%
z_s = []
as_TP = 0
as_FP = 0
for ars in arpicks:
    for hs in hands:
        if ars[0] == hs[0]:
            a = datetime.strptime(hs[1], '%Y-%m-%dT%H:%M:%S.%f')
            b = datetime.strptime(ars[1], '%Y-%m-%dT%H:%M:%S.%f')
            diff = a - b
            z_s.append(diff.total_seconds())
            if abs(diff.total_seconds()) <= TPlim:
                as_TP += 1
            else:
                as_FP += 1
                
print('ARPick S true positives TP: ', as_TP)
print('ARPick S false positives FP: ', as_FP)
as_FN = len(hands) - as_TP
print('ARPick S false negatives: FN ', as_FN)

as_precision = as_TP / (as_TP + as_FP)
as_recall = as_TP / (as_TP + as_FN)
as_f1 = 2 * as_precision * as_recall / (as_precision + as_recall)

print(len(z_s))
print(z_s[:100])
# Out:
# ARPick S true positives TP:  839
# ARPick S false positives FP:  2752
# ARPick S false negatives: FN  2845
# 3591
# [-2.25, -0.09, -0.96, -1.76, -2.29, -0.55, -0.85, -3.98, -0.09, -2.42, 0.32, -1.23, -2.9, -1.81, 0.03, 0.29, -0.14, -0.38, -0.49, -0.65, -0.16, 0.33, -0.54, 0.15, -1.52, 0.32, -2.22, 0.0, -2.43, -2.97, -0.02, -1.05, 6.47, -2.73, 0.3, -3.64, -0.59, 0.83, -0.18, -1.78, -0.59, -1.14, 17.96, -3.38, -2.09, -2.81, -0.29, 0.4, -1.48, -0.43, 0.33, -2.62, -0.16, -0.91, -2.42, -0.7, -1.01, 0.89, -0.33, -0.45, 0.02, 0.01, -0.55, -0.55, 3.49, 0.29, 0.28, 0.0, -0.08, 4.54, 0.36, 2.26, 15.42, -0.14, -0.47, 0.07, -0.89, -0.81, 0.57, -1.73, 1.38, -1.34, 0.64, -5.84, -0.11, 0.06, 0.2, -0.11, -0.24, -0.4, -0.5, 0.76, -0.62, -0.32, 0.4, 0.65, -0.48, -0.33, 0.9, -0.71]

# %%
x_p_abs_mean = sum(abs(x) for x in x_p) / len(x_p)
x_p_mean = mean(x_p)
x_p_mae = sum(abs(x - x_p_mean) for x in x_p) / len(x_p)
x_p_median = median(x_p)
x_p_rmse = mean([i ** 2 for i in x_p]) ** 0.5
x_s_abs_mean = sum(abs(x) for x in x_s) / len(x_s)
x_s_mean = mean(x_s)
x_s_mae = sum(abs(x - x_s_mean) for x in x_s) / len(x_s)
x_s_median = median(x_s)
x_s_rmse = mean([i ** 2 for i in x_s]) ** 0.5

# %%
z_p_abs_mean = sum(abs(x) for x in z_p) / len(z_p)
z_p_mean = mean(z_p)
z_p_mae = sum(abs(x - z_p_mean) for x in z_p) / len(z_p)
z_p_median = median(z_p)
z_p_rmse = mean([i ** 2 for i in z_p]) ** 0.5
z_s_abs_mean = sum(abs(x) for x in z_s) / len(z_s)
z_s_mean = mean(z_s)
z_s_mae = sum(abs(x - z_s_mean) for x in z_s) / len(z_s)
z_s_median = median(z_s)
z_s_rmse = mean([i ** 2 for i in z_s]) ** 0.5

# %%
print(tabulate([['Precision P', pp_precision, ap_precision], 
                ['Precision S', ps_precision, as_precision],
                ['Recall P', pp_recall, ap_recall],
                ['Recall S', ps_recall, as_recall],
                ['F1 P', pp_f1, ap_f1],
                ['F1 S', ps_f1, as_f1], 
                ['µ(∆t) P', x_p_mean, z_p_mean],
                ['µ(∆t) S', x_s_mean, z_s_mean], 
                ['µ(|∆t|) P', x_p_abs_mean, z_p_abs_mean],
                ['µ(|∆t|) S', x_s_abs_mean, z_s_abs_mean], 
                ['Wrong Metric P', abs(x_p_mean), abs(z_p_mean)],
                ['Wrong Metric S', abs(x_s_mean), abs(z_s_mean)],
                ['Median P', x_p_median, z_p_median],
                ['Median S', x_s_median, z_s_median],
                ['Mean Absolute Error (MAE) P', x_p_mae, z_p_mae],
                ['Mean Absolute Error (MAE) S', x_s_mae, z_s_mae],
                ['Root Mean Square Error (RMSE) P', x_p_rmse, z_p_rmse],
                ['Root Mean Square Error (RMSE) S', x_s_rmse, z_s_rmse]], headers=['Phasenet', 'ARPick']))
# Out:
#                                    Phasenet     ARPick
# -------------------------------  ----------  ---------
# Precision P                       0.556419    0.398646
# Precision S                       0.467811    0.23364
# Recall P                          0.886356    0.39859
# Recall S                          0.943723    0.227742
# F1 P                              0.683662    0.398618
# F1 S                              0.625538    0.230653
# µ(∆t) P                          -0.184926    0.295943
# µ(∆t) S                           0.0328898  -0.865338
# µ(|∆t|) P                         0.65493     1.32868
# µ(|∆t|) S                         0.687403    1.58181
# Wrong Metric P                    0.184926    0.295943
# Wrong Metric S                    0.0328898   0.865338
# Median P                         -0.01        0.06
# Median S                          0          -0.66
# Mean Absolute Error (MAE) P       0.697176    1.35773
# ...

# %%
#with open('./AA/AAS_confidence_analysis.csv', 'a', newline='') as file:
#    writer = csv.writer(file)
#    writer.writerow([Pplim, x_p_mean, x_s_mean, x_p_abs_mean, x_s_abs_mean, x_p_mae, x_s_mae, x_p_rmse, x_s_rmse, 
#                     abs(x_p_mean), abs(x_s_mean), phasep_lim, phases_lim])

# %%
rows = []
with open('./AA/AAS_confidence_analysis.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        rows.append([float(row[0]), float(row[1]), float(row[2]), float(row[3]), float(row[4]), float(row[5]), 
                     float(row[6]), float(row[7]), float(row[8]), float(row[9]), float(row[10]), float(row[11]), float(row[12])])
nprows = np.array(rows).T
par_vals = [z_p_rmse] * 6
sar_vals = [z_s_rmse] * 6

fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharex=True, figsize=(15, 5))
fig.suptitle('Positive Classification Threshold (PCT) Analysis of PhaseNet Picks')

ax0.set_title('a', loc="left")
ax0.plot(nprows[0], nprows[7], label='PhaseNet-Human RMSE P')
ax0.plot(nprows[0], par_vals, label='ARPick-Human RMSE P')
ax0.set_xlabel('PhaseNet P Pick PCT')
ax0.set_ylabel('RMSE')
ax0.legend()

ax1.set_title('b', loc="left")
ax1.plot(nprows[0], nprows[8], label='PhaseNet-Human RMSE S')
ax1.plot(nprows[0], sar_vals, label='ARPick-Human RMSE S')
ax1.set_xlabel('PhaseNet S Pick PCT')
ax1.set_ylabel('RMSE')
ax1.legend()

ax2.set_title('c', loc="left")
ax2.plot(nprows[0], nprows[11]/1000, label='PhaseNet P Picks')
ax2.plot(nprows[0], nprows[12]/1000, label='PhaseNet S Picks')
ax2.set_xlabel('PhaseNet PCT')
ax2.set_ylabel('Number of Picks x 1000')
ax2.plot(0.6, 4.9, 'ro')
ax2.plot(0.4, 4.9, 'ro')
ax2.text(0.3, 1.5, 'Human P Picks: '+ str(format(len(handp))), 
        fontsize=10, verticalalignment='top')
ax2.text(0.3, 1.3, 'Human S Picks: '+ str(format(len(hands))), 
        fontsize=10, verticalalignment='top')
ax2.legend()

plt.savefig(path_project_home + '/AAS-phaseNet-Probs-en.jpg', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True, figsize=(15, 5))

fig.suptitle('Histograms of Residuals: PhaseNet vs ARPick P Pick Performances against Human')
props = dict(boxstyle='round', facecolor='white', alpha=0.5)

ax0.hist(x=x_p, bins=100, color='#0504aa', alpha=0.7, rwidth=0.90)
ax0.set_ylim([0, 1550])
ax0.grid(axis='y', alpha=0.75)
ax0.set_xlabel('Sec')
ax0.set_ylabel('Frequency')
ax0.set_title('a', loc="left")
ax0.set_title('PhaseNet vs Human P picks', loc="center")
ax0.set_xlim([-5, +5])
ax0.text(-4.75, 1475, 'µ(∆t) P: '+ str(format(round(x_p_mean,2), ".2f")) + ' sec', fontsize=10, verticalalignment='top', bbox=props)
#ax0.text(-4.75, 1350, 'Median: '+ str(format(round(x_p_median,2), ".2f"))+ ' sec', fontsize=10, verticalalignment='top', bbox=props)
#ax0.text(-4.75, 1225, 'RMSE: '+ str(format(round(x_p_rmse,2), ".2f")), fontsize=10, verticalalignment='top', bbox=props)
ax0.text(-4.75, 1350, '[-5, +5] Out: '+ str(len([i for i in x_p if abs(float(i))> 5])), fontsize=10, verticalalignment='top', bbox=props)
#ax0.text(1.5, 1225, 'PhaseNet P Picks: '+ str(phasep_lim), fontsize=10, verticalalignment='top', bbox=props)
#ax0.text(1.5, 1100, 'Human P Picks: '+ str(len((handp))), fontsize=10, verticalalignment='top', bbox=props)

ax1.hist(x=z_p, bins=100, color='#0504aa', alpha=0.7, rwidth=0.90)
ax0.set_ylim([0, 1550])
ax1.grid(axis='y', alpha=0.75)
ax1.set_xlabel('Sec')
ax1.set_ylabel('Frequency')
ax1.set_title('b', loc="left")
ax1.set_title('ARPick vs Human P picks', loc="center")
ax1.set_xlim([-5, +5])
ax1.text(-4.75, 1475, 'µ(∆t) P: '+ str(format(round(z_p_mean,2), ".2f")) + ' sec', fontsize=10, verticalalignment='top', bbox=props)
#ax1.text(-4.75, 1350, 'Median: '+ str(format(round(z_p_median,2), ".2f"))+ ' sec', fontsize=10, verticalalignment='top', bbox=props)
#ax1.text(-4.75, 1225, 'RMSE: '+ str(format(round(z_p_rmse,2), ".2f")), fontsize=10, verticalalignment='top', bbox=props)
ax1.text(-4.75, 1350, '[-5, +5] Out: '+ str(len([i for i in z_p if abs(float(i))> 5])), fontsize=10, verticalalignment='top', bbox=props)
#ax1.text(1.5, 1225, 'ArPick P Picks: '+ str(len(arpickp)), fontsize=10, verticalalignment='top', bbox=props)
#ax1.text(1.5, 1100, 'Human P Picks: '+ str(len((handp))), fontsize=10, verticalalignment='top', bbox=props)

plt.savefig(path_project_home + '/AAS-P-phasenet-arpick-en.jpg', dpi=300, bbox_inches='tight')

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True, figsize=(15, 5))

fig.suptitle('Histograms of Residuals: PhaseNet vs ARPick S Pick Performances against Human')
props = dict(boxstyle='round', facecolor='white', alpha=0.5)

ax0.hist(x=x_p, bins=100, color='#0504aa', alpha=0.7, rwidth=0.90)
ax0.set_ylim([0, 1550])
ax0.grid(axis='y', alpha=0.75)
ax0.set_xlabel('Sec')
ax0.set_ylabel('Frequency')
ax0.set_title('a', loc="left")
ax0.set_title('PhaseNet vs Human S picks', loc="center")
ax0.set_xlim([-5, +5])
ax0.text(-4.75, 1475, 'µ(∆t) S: '+ str(format(round(x_s_mean,2), ".2f")) + ' sec', fontsize=10, verticalalignment='top', bbox=props)
#ax0.text(-4.75, 1350, 'Median: '+ str(format(round(x_s_median,2), ".2f"))+ ' sec', fontsize=10, verticalalignment='top', bbox=props)
#ax0.text(-4.75, 1225, 'RMSE: '+ str(format(round(x_s_rmse,2), ".2f")), fontsize=10, verticalalignment='top', bbox=props)
ax0.text(-4.75, 1350, '[-5, +5] Out: '+ str(len([i for i in x_s if abs(float(i))> 5])), fontsize=10, verticalalignment='top', bbox=props)
#ax0.text(1.5, 1225, 'PhaseNet P Picks: '+ str(phases_lim), fontsize=10, verticalalignment='top', bbox=props)
#ax0.text(1.5, 1100, 'Human P Picks: '+ str(len((hands))), fontsize=10, verticalalignment='top', bbox=props)
#ax0.text(1.5, 1475, 'PhaseNet S Picks\nand Human S Picks\nIntersection: '+ str(len((x_s))), fontsize=10, verticalalignment='top', bbox=props)

ax1.hist(x=z_p, bins=100, color='#0504aa', alpha=0.7, rwidth=0.90)
ax1.set_ylim([0, 1550])
ax1.grid(axis='y', alpha=0.75)
ax1.set_xlabel('Sec')
ax1.set_ylabel('Frequency')
ax1.set_title('b', loc="left")
ax1.set_title('ARPick vs Human S picks', loc="center")
ax1.set_xlim([-5, +5])
ax1.text(-4.75, 1475, 'µ(∆t) S: '+ str(format(round(z_s_mean,2), ".2f")) + ' sec', fontsize=10, verticalalignment='top', bbox=props)
#ax1.text(-4.75, 1350, 'Median: '+ str(format(round(z_s_median,2), ".2f"))+ ' sec', fontsize=10, verticalalignment='top', bbox=props)
#ax1.text(-4.75, 1225, 'RMSE: '+ str(format(round(z_s_rmse,2), ".2f")), fontsize=10, verticalalignment='top', bbox=props)
ax1.text(-4.75, 1350, '[-5, +5] Out: '+ str(len([i for i in z_s if abs(float(i))> 5])), fontsize=10, verticalalignment='top', bbox=props)
#ax1.text(1.5, 1225, 'ArPick P Picks: '+ str(len(arpicks)), fontsize=10, verticalalignment='top', bbox=props)
#ax1.text(1.5, 1100, 'İnsan P Picks: '+ str(len((hands))), fontsize=10, verticalalignment='top', bbox=props)
#ax1.text(1.5, 1475, 'ARPick S Picks\nand Human S Picks\nIntersection: '+ str(len((z_s))), fontsize=10, verticalalignment='top', bbox=props)

plt.savefig(path_project_home + '/AAS-S-phasenet-arpick-en.jpg', dpi=300, bbox_inches='tight')

# %%
mags = []
for eq in seqs:
    mags.append(float(eq.split('/')[0].split('_')[1][-3:]))
print(len(mags))
print(mags[0:100])
# Out:
# 918
# [2.0, 1.3, 1.5, 2.3, 1.2, 2.1, 2.8, 1.3, 1.5, 3.8, 2.2, 1.5, 2.3, 1.4, 1.7, 1.6, 1.8, 3.6, 1.4, 1.7, 1.7, 1.7, 2.6, 1.8, 1.6, 1.6, 1.7, 2.6, 2.1, 3.3, 1.6, 2.5, 2.3, 2.1, 3.3, 2.2, 1.6, 2.1, 1.6, 1.6, 1.3, 1.3, 1.6, 1.9, 2.5, 2.5, 2.1, 1.6, 2.2, 1.8, 2.0, 1.6, 1.4, 2.0, 1.8, 1.6, 2.1, 1.7, 2.7, 2.6, 2.3, 1.4, 3.2, 2.1, 2.6, 2.4, 2.6, 2.5, 2.3, 2.1, 1.4, 2.6, 2.2, 2.7, 1.5, 1.6, 2.0, 1.9, 1.1, 2.3, 2.1, 2.5, 1.4, 1.9, 1.7, 2.1, 2.4, 1.8, 1.9, 1.9, 2.0, 2.3, 1.9, 3.8, 3.9, 1.5, 3.6, 2.1, 2.2, 1.5]

# %%
smagsmatched = []
smagsadditional = []
spicksmatched = 0
spicksadditional = 0
eqcheck = []
eqcheckadd = []
for ps in phases:
    matched = False
    for hs in hands:
        if hs[0] == ps[0]:
            if ps[0].split('/')[0] not in eqcheck:
                smagsmatched.append(float(ps[0].split('/')[0].split('_')[1][-3:]))
                eqcheck.append(ps[0].split('/')[0])
            spicksmatched += 1
            matched = True
    if not matched:
        if ps[0].split('/')[0] not in eqcheckadd:
            smagsadditional.append(float(ps[0].split('/')[0].split('_')[1][-3:]))
            eqcheckadd.append(ps[0].split('/')[0])
        spicksadditional += 1
print(len(smagsmatched), spicksmatched)
print(smagsmatched[0:100])
print(len(smagsadditional), spicksadditional)
print(smagsadditional[0:100])
# Out:
# 912 3139
# [2.0, 1.3, 1.5, 2.3, 1.2, 2.1, 2.8, 1.3, 1.5, 3.8, 2.2, 1.5, 2.3, 1.4, 1.7, 1.6, 1.8, 3.6, 1.4, 1.7, 1.7, 1.7, 2.6, 1.8, 1.6, 1.6, 1.7, 2.6, 2.1, 3.3, 1.6, 2.5, 2.3, 2.1, 3.3, 2.2, 1.6, 2.1, 1.6, 1.6, 1.3, 1.3, 1.6, 1.9, 2.5, 2.5, 2.1, 1.6, 2.2, 1.8, 2.0, 1.6, 1.4, 2.0, 1.8, 1.6, 2.1, 1.7, 2.7, 2.6, 2.3, 1.4, 3.2, 2.1, 2.6, 2.4, 2.6, 2.5, 2.1, 1.4, 2.6, 2.2, 2.7, 1.5, 1.6, 2.0, 1.9, 1.1, 2.3, 2.1, 2.5, 1.4, 1.9, 1.7, 2.1, 2.4, 1.8, 1.9, 1.9, 2.0, 2.3, 1.9, 3.8, 3.9, 1.5, 3.6, 2.1, 2.2, 1.5, 3.1]
# 766 2530
# ...

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True, figsize=(15, 5))
props = dict(boxstyle='round', facecolor='white', alpha=0.5)

fig.suptitle('Histogram: Magnitude Analysis for Earthquakes by Extra PhaseNet S Picks vs Earthquakes by PhaseNet S Picks Matching Handpicks')

ax0.hist(x=smagsadditional, bins=15, color='#0504aa', alpha=0.7, rwidth=0.90)
ax0.set_ylim([0, 225])
ax0.grid(axis='y', alpha=0.75)
ax0.set_xlabel('Magnitude')
ax0.set_ylabel('Frequecy')
ax0.set_title('a', loc="left")
ax0.set_title('Earthquakes by Extra PhaseNet S Picks', loc="center")
ax0.text(3.3, 200, 'Magnitude Mean: '+ str(round(mean(smagsadditional),3)), fontsize=10, verticalalignment='top', bbox=props)
#ax0.text(3.3, 200, 'Median: '+ str(round(median(smagsadditional),1)), fontsize=10, verticalalignment='top', bbox=props)
ax0.text(3.3, 215, 'Earthquakes: '+ str(round(len(smagsadditional),1)), fontsize=10, verticalalignment='top', bbox=props)
#ax0.text(2.9, 170, 'Extra PhaseNet S Picks: '+ str(spicksadditional), fontsize=10, verticalalignment='top', bbox=props)

ax1.hist(x=smagsmatched, bins=15, color='#0504aa', alpha=0.7, rwidth=0.90)
ax1.set_ylim([0, 225])
ax1.grid(axis='y', alpha=0.75)
ax1.set_xlabel('Magnitude')
ax1.set_ylabel('Frequency')
ax1.set_title('b', loc="left")
plt.title('Earthquakes by PhaseNet S Picks Matching Handpicks')
ax1.text(3.3, 200, 'Mean: '+ str(round(mean(smagsmatched),3)), fontsize=10, verticalalignment='top', bbox=props)
#ax1.text(3.3, 185, 'Median: '+ str(round(median(smagsmatched),1)), fontsize=10, verticalalignment='top', bbox=props)
ax1.text(3.3, 215, 'Earthquakes: '+ str(round(len(smagsmatched),1)), fontsize=10, verticalalignment='top', bbox=props)
#ax1.text(2.9, 170, 'Human and PhaseNet\nS Picks Intersection: '+ str(spicksmatched), fontsize=10, verticalalignment='top', bbox=props)

plt.savefig(path_project_home + '/AAS-eqmagdiff-en.jpg', dpi=300, bbox_inches='tight')

# %%
n, bins, patches = plt.hist(x=mags, bins=15, color='#0504aa',
                            alpha=0.7, rwidth=0.90)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.title('Histogram: Earthquake Magnitudes of Study Data')
ax = plt.gca()
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
#ax.text(0.02, 0.97, 'Mean: '+ str(round(mean(mags),1)), transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=props)
#ax.text(0.02, 0.90, 'Median: '+ str(round(median(mags),1)), transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=props)
ax.text(0.7, 0.97, 'Earthquakes: '+ str(len(seqs))[:5], transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=props)
#ax.text(0.02, 0.76, 'Stations: '+ str(len(pstations))[:5], transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=props)
#ax.text(0.69, 0.83, 'Min. Mag.: '+ str(min(mags))[:5], transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=props)
#ax.text(0.69, 0.76, 'Max. Mag.: '+ str(max(mags))[:5], transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=props)
plt.savefig(path_project_home + '/AAS-all-eqs-en.jpg', dpi=300, bbox_inches='tight')
